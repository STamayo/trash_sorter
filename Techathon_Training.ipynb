# %% [markdown]
# <a href="https://colab.research.google.com/github/STamayo/trash_sorter/blob/main/Techathon_Training.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !nvidia-smi
# Out:
# Thu Mar 27 16:22:40 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   47C    P8             10W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
import os
HOME = os.getcwd()
HOME
# Out:
# '/content'

# %%
# !pip install ultralytics==8.2.103 -q

from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.2.103 🚀 Python-3.11.11 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 41.0/112.6 GB disk)

# %%
from ultralytics import YOLO

from IPython.display import display, Image

# %%
# !unzip dataset2.zip
# Out:
# Archive:  dataset2.zip
#    creating: dataset2/
#   inflating: dataset2/dataset.yaml
#    creating: dataset2/images/
#    creating: dataset2/images/train/
#   inflating: dataset2/images/train/WIN_20250327_22_37_22_Pro.jpg
#   inflating: dataset2/images/train/WIN_20250327_22_37_25_Pro.jpg
#   inflating: dataset2/images/train/WIN_20250327_22_37_27_Pro.jpg
#   inflating: dataset2/images/train/WIN_20250327_22_37_29_Pro.jpg
#   inflating: dataset2/images/train/WIN_20250327_22_37_30_Pro.jpg
#   inflating: dataset2/images/train/WIN_20250327_22_37_32_Pro.jpg
#   inflating: dataset2/images/train/WIN_20250327_22_37_33_Pro.jpg
#   inflating: dataset2/images/train/WIN_20250327_22_37_35_Pro.jpg
#   inflating: dataset2/images/train/WIN_20250327_22_37_37_Pro.jpg
#   inflating: dataset2/images/train/WIN_20250327_22_37_38_Pro.jpg
#   inflating: dataset2/images/train/WIN_20250327_22_37_40_Pro.jpg
#   inflating: dataset2/images/train/WIN_20250327_22_37_41_Pro.jpg
# ...

# %%
# %cd {HOME}/datasets

# !yolo task=detect mode=train model=yolov8l.pt data='dataset/dataset.yaml' epochs=50 imgsz=640 plots=True
# Out:
# /content/datasets
# New https://pypi.org/project/ultralytics/8.3.97 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.2.103 🚀 Python-3.11.11 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
# %cd {HOME}
Image(filename=f'{HOME}/datasets/runs/detect/train4/confusion_matrix.png', width=600)
# Out:
# /content

# %%
# %cd {HOME}
Image(filename=f'{HOME}/datasets/runs/detect/train4/results.png', width=600)
# Out:
# /content
